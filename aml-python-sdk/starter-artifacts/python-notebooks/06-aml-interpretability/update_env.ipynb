# %% [markdown]
# Run the cells below, one at a time, to update your environment for the **Model interpretability with Azure Machine Learning service** quickstart.

# %%
# !pip install azureml-sdk[notebooks,explain,automl,contrib]==1.0.74

# %%
# !pip install matplotlib==3.1.2
